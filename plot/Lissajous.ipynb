# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
phase_set=[0, 90, 180, 270, 360]
phase_measure=[-52.537, 36.383, 126.38, 218.8, 360-50.989]

# %%
plt.plot(phase_set, phase_measure)
plt.scatter(phase_set, phase_measure,c='r')
plt.xlabel('set phase')
plt.ylabel('measured phase')
# Out:
# Text(0, 0.5, 'measured phase')
